# %%
import pandas as pd

# %%
file_path = '../../data/processed/feature_selected_data.parquet'
df = pd.read_parquet(file_path, engine= 'pyarrow')

# %%
df.columns
# Out:
# Index(['id_prenotazione', 'id_paziente', 'data_nascita', 'sesso',
#        'regione_residenza', 'asl_residenza', 'provincia_residenza',
#        'comune_residenza', 'tipologia_servizio', 'descrizione_attivita',
#        'data_contatto', 'regione_erogazione', 'asl_erogazione',
#        'provincia_erogazione', 'struttura_erogazione',
#        'codice_struttura_erogazione', 'tipologia_struttura_erogazione',
#        'id_professionista_sanitario', 'tipologia_professionista_sanitario',
#        'data_erogazione', 'durata_erogazione_min', 'eta'],
#       dtype='object')

# %% [markdown]
# - 'id_paziente' - NO
# - 'data_nascita' -  NO
# - 'sesso' - SI, con altre
# - 'regione_residenza' - SI
# - 'asl_residenza' - SI
# - 'provincia_residenza' - SI
# - 'comune_residenza' - SI
# - 'tipologia_servizio' - NO
# - 'descrizione_attivita' - SI
# - 'data_contatto' - NO
# - 'regione_erogazione' -  SI
# - 'asl_erogazione' - SI
# - 'provincia_erogazione' - SI
# - 'struttura_erogazione' - SI
# - 'codice_struttura_erogazione' - NO
# - 'tipologia_struttura_erogazione' - SI
# - 'id_professionista_sanitario' -  NO
# - 'tipologia_professionista_sanitario' - SI
# - 'data_erogazione' - NO
# - 'durata_erogazione_min' - NO
# - 'eta' - SI

# %%
df['data_erogazione'] = pd.to_datetime(df['data_erogazione'], utc=True)

df['anno'] = df['data_erogazione'].dt.year
df['quadrimestre'] = df['data_erogazione'].dt.quarter

# %%
df.head()
# Out:
#    id_prenotazione       id_paziente              data_nascita   sesso  \
# 0  JUOCPQCUG1H96QO  LCWFXF28X79P382V 1980-04-24 00:00:00+00:00    male
# 1  XDP99NXRHPOYFYU  LRFZOI94E58U012I 1972-01-30 00:00:00+00:00  female
# 2  6VYI0AK57ECO5WU  JOBCGJ98A04B765H 1986-06-27 00:00:00+00:00    male
# 3  VLFS5J9E3Q74Q2W  TKROSE51Z77Q065E 1967-10-21 00:00:00+00:00  female
# 4  XD8SZX9JOVCMEXW  WRRVSK73Z45L640S 1963-08-24 00:00:00+00:00    male
#
#   regione_residenza               asl_residenza provincia_residenza  \
# 0          Piemonte                         CN1               Cuneo
# 1           Toscana  AZIENDA USL TOSCANA CENTRO             Firenze
# 2    Emilia romagna         AZIENDA USL BOLOGNA             Bologna
# 3          Campania      A.S.L. NAPOLI 1 CENTRO              Napoli
# 4           Abruzzo                     PESCARA             Pescara
#
#   comune_residenza tipologia_servizio  \
# 0          Fossano     Teleassistenza
# 1        Calenzano     Teleassistenza
# 2          Bologna     Teleassistenza
# 3           Napoli     Teleassistenza
# 4          Pescara     Teleassistenza
#
#                                 descrizione_attivita  ...  \
# 0  Insegnamento al paziente e/o alla sua famiglia...  ...
# 1  Prestazione infermieristica connessa alla nece...  ...
# 2                             Prestazione dietistica  ...
# 3                           Psicoterapia individuale  ...
# 4                             Prestazione dietistica  ...
#
#                       struttura_erogazione codice_struttura_erogazione  \
# 0            AZ. OSPEDAL. S. CROCE E CARLE                       10906
# 1                AZIENDA OSPEDALIERA MEYER                       90904
# 2  PRESIDIO OSPEDALIERO UNICO - AZIENDA DI                       80053
# 3            A.O.R.N. SANTOBONO-PAUSILIPON                      150902
# 4             P.O. 'SPIRITO SANTO' PESCARA                      130018
#
#       tipologia_struttura_erogazione id_professionista_sanitario  \
# 0                Azienda Ospedaliera            MZRAER00D13A287J
# 1  Azienda Ospedaliera Universitaria            EBCRPU12T24U316I
# 2        Ospedale a gestione diretta            PMEJNL62M27F357I
# 3                Azienda Ospedaliera            VNNRMQ15C69W200K
# 4        Ospedale a gestione diretta            GIQCNR34T04P154U
#
#   tipologia_professionista_sanitario           data_erogazione  \
# 0                         Infermiere 2019-02-04 10:00:00+00:00
# 1                         Infermiere 2019-02-01 10:00:00+00:00
# 2                           Dietista 2019-02-03 06:00:00+00:00
# 3                          Psicologo 2019-02-01 06:00:00+00:00
# 4                           Dietista 2019-02-05 14:00:00+00:00
#
#   durata_erogazione_min eta  anno quadrimestre
# 0                2925.0  44  2019            1
# 1                1895.0  52  2019            1
# 2                1165.0  38  2019            1
# 3                1969.0  56  2019            1
# 4                3099.0  61  2019            1
#
# [5 rows x 24 columns]

# %%
df[['anno', 'quadrimestre', 'eta']].corr()
# Out:
#                   anno  quadrimestre       eta
# anno          1.000000     -0.120129 -0.005918
# quadrimestre -0.120129      1.000000 -0.004987
# eta          -0.005918     -0.004987  1.000000
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
grouped = df.groupby(['anno', 'quadrimestre', 'regione_erogazione']).size().reset_index(name='num_servizi')

# %%
grouped.sort_values(by=['num_servizi'], ascending=True)
# Out:
#      anno  quadrimestre    regione_erogazione  num_servizi
# 19   2019             1         Valle d`aosta           23
# 40   2019             2         Valle d`aosta           31
# 12   2019             1  Prov. auton. bolzano           43
# 10   2019             1                Molise           43
# 313  2022             3         Valle d`aosta           44
# ..    ...           ...                   ...          ...
# 218  2021             3             Lombardia         5475
# 197  2021             2             Lombardia         5554
# 134  2020             3             Lombardia         5735
# 176  2021             1             Lombardia         6785
# 155  2020             4             Lombardia         7055
#
# [336 rows x 4 columns]

# %%
# Calcolo dell'incremento per ogni quadrimestre
grouped['incremento'] = grouped.groupby(['quadrimestre', 'regione_erogazione'])['num_servizi'].diff()

# %%
grouped.sort_values(by=['incremento'], ascending=False)
# Out:
#      anno  quadrimestre regione_erogazione  num_servizi  incremento
# 155  2020             4          Lombardia         7055      3297.0
# 92   2020             1          Lombardia         4379      2883.0
# 176  2021             1          Lombardia         6785      2406.0
# 153  2020             4              Lazio         5024      2285.0
# 150  2020             4           Campania         4808      2099.0
# ..    ...           ...                ...          ...         ...
# 79   2019             4            Sicilia         2259         NaN
# 80   2019             4            Toscana          784         NaN
# 81   2019             4             Umbria          328         NaN
# 82   2019             4      Valle d`aosta           54         NaN
# 83   2019             4             Veneto         2262         NaN
#
# [336 rows x 5 columns]

# %%
mask = (grouped['regione_erogazione'] == 'Sicilia') & (grouped['quadrimestre'] == 4)
grouped[mask]
# Out:
#      anno  quadrimestre regione_erogazione  num_servizi  incremento
# 79   2019             4            Sicilia         2259         NaN
# 163  2020             4            Sicilia         4122      1863.0
# 247  2021             4            Sicilia         2711     -1411.0
# 331  2022             4            Sicilia         2615       -96.0

# %%
# Elimino i campioni con incremento nullo, sono quelli del 2019 (primo anno storicizzato)
# grouped = grouped.dropna(subset=['incremento'])

# %%
# Calcolo dell'incremento percentuale
grouped['incremento_percentuale'] = grouped['incremento'] / grouped.groupby(['quadrimestre', 'regione_erogazione'])['num_servizi'].shift(1) * 100   # shift(1) per avere il valore precedente

# Calcolo dell'incremento percentuale medio per ogni coppia di quadrimestre e regione_erogazione
incremento_percentuale_medio = grouped.groupby(['quadrimestre', 'regione_erogazione'])['incremento_percentuale'].mean().reset_index()

# Visualizza il risultato
app = incremento_percentuale_medio.sort_values(by=['incremento_percentuale'], ascending=False)
app
# Out:
#     quadrimestre     regione_erogazione  incremento_percentuale
# 12             1   Prov. auton. bolzano               85.685368
# 5              1  Friuli venezia giulia               78.437573
# 9              1                 Marche               78.050608
# 8              1              Lombardia               72.727056
# 6              1                  Lazio               72.588215
# ..           ...                    ...                     ...
# 58             3                Sicilia                8.986435
# 45             3               Campania                7.511571
# 43             3             Basilicata                6.837010
# 30             2                 Marche                3.745533
# 31             2                 Molise                1.636089
#
# [84 rows x 3 columns]

# %%
mask = (grouped['regione_erogazione'] == 'Sicilia') & (grouped['quadrimestre'] == 4)
grouped[mask]
# Out:
#      anno  quadrimestre regione_erogazione  num_servizi  incremento  \
# 79   2019             4            Sicilia         2259         NaN
# 163  2020             4            Sicilia         4122      1863.0
# 247  2021             4            Sicilia         2711     -1411.0
# 331  2022             4            Sicilia         2615       -96.0
#
#      incremento_percentuale
# 79                      NaN
# 163               82.470120
# 247              -34.230956
# 331               -3.541129

# %%
mask = (incremento_percentuale_medio['regione_erogazione'] == 'Sicilia') & (incremento_percentuale_medio['quadrimestre'] == 4)
incremento_percentuale_medio[mask]
# Out:
#     quadrimestre regione_erogazione  incremento_percentuale  \
# 79             4            Sicilia               14.899345
#
#    incremento_teleassistenze
# 79             low_increment

# %% [markdown]
# Per studiare i dati e determinare le soglie appropriate per l'assegnazione delle etichette, puoi seguire alcuni passaggi che ti aiuteranno a comprendere meglio la distribuzione degli incrementi percentuali. Ecco una guida pratica su come fare:
#
# 1. Esplora la Distribuzione degli Incrementi Percentuali
# Distribuzione:
# - Usa un istogramma o un grafico a densità per visualizzare la distribuzione degli incrementi percentuali.
# - Statistica Descrittiva: Calcola metriche come la media, la mediana, i quartili, e la deviazione standard.
#
# 2. Identifica Valori Estremi (Outliers)
# - Gli outlier possono influenzare significativamente le soglie. Identificare e, se necessario, trattare questi valori può essere utile.
# - Puoi usare boxplot o interquartile range (IQR) per individuare gli outlier.
#
# 3. Segmentazione basata su Quartili
# - I quartili (Q1, Q2, Q3) dividono i dati in quattro parti uguali. Usarli per definire le soglie può aiutarti a segmentare in modo equilibrato.
#
# 4. Visualizzazione dei Dati
# - Scatter plot: Un grafico scatter può aiutare a vedere la relazione tra l'anno e l'incremento percentuale.
# - Boxplot: Un boxplot mostra la distribuzione e può evidenziare outlier e valori medi.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Calcola la distribuzione degli incrementi percentuali
plt.figure(figsize=(10, 6))
sns.histplot(incremento_percentuale_medio['incremento_percentuale'], bins=30, kde=True)
plt.title('Distribuzione degli Incrementi Percentuali')
plt.xlabel('Incremento Percentuale Medio')
plt.ylabel('Frequenza')
plt.show()

# %%
# Statistiche descrittive
descr = incremento_percentuale_medio['incremento_percentuale'].describe()
print(descr)
# Out:
# count    84.000000
# mean     27.496611
# std      23.395760
# min       1.636089
# 25%      12.056031
# 50%      15.252433
# 75%      40.652561
# max      85.685368
# Name: incremento_percentuale, dtype: float64

# %%
# Boxplot per identificare outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x=incremento_percentuale_medio['incremento_percentuale'])
plt.title('Boxplot degli Incrementi Percentuali')
plt.xlabel('Incremento Percentuale')
plt.show()

# %%
# TODO: dobbiamo identificare anche il decremento?

def classify_increment(value):
    constat_increment = 5 
    low_increment = 15
    medium_increment = 40


    if value <= constat_increment:
        return 'constant_increment'
    elif value <= low_increment:
        return 'low_increment'
    elif value <= medium_increment:
        return 'medium_increment'
    elif value > medium_increment:
        return 'high_increment'
    else:
        return 'decrement'

# %%
incremento_percentuale_medio['incremento_teleassistenze'] = incremento_percentuale_medio['incremento_percentuale'].apply(classify_increment)

# %%
incremento_percentuale_medio.sort_values(by=['incremento_percentuale'], ascending=False)
# Out:
#     quadrimestre     regione_erogazione  incremento_percentuale  \
# 12             1   Prov. auton. bolzano               85.685368
# 5              1  Friuli venezia giulia               78.437573
# 9              1                 Marche               78.050608
# 8              1              Lombardia               72.727056
# 6              1                  Lazio               72.588215
# ..           ...                    ...                     ...
# 58             3                Sicilia                8.986435
# 45             3               Campania                7.511571
# 43             3             Basilicata                6.837010
# 30             2                 Marche                3.745533
# 31             2                 Molise                1.636089
#
#    incremento_teleassistenze
# 12            high_increment
# 5             high_increment
# 9             high_increment
# 8             high_increment
# 6             high_increment
# ..                       ...
# 58             low_increment
# 45             low_increment
# 43             low_increment
# 30        constant_increment
# 31        constant_increment
#
# [84 rows x 4 columns]

# %%
df['incremento_teleassistenze'] = df.apply(lambda x: incremento_percentuale_medio.loc[(incremento_percentuale_medio['regione_erogazione'] == x['regione_erogazione']) & (incremento_percentuale_medio['quadrimestre'] == x['quadrimestre'])]['incremento_teleassistenze'].values[0], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['incremento_teleassistenze'] = df.apply(lambda x: incremento_percentuale_medio.loc[(incremento_percentuale_medio['regione_erogazione'] == x['regione_erogazione']) & (incremento_percentuale_medio['quadrimestre'] == x['quadrimestre'])]['incremento_teleassistenze'].values[0], axis=1)
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[21], line 1, in <lambda>(x)
# ----> 1 df['incremento_teleassistenze'] = df.apply(lambda x: incremento_percentuale_medio.loc[(incremento_percentuale_medio['regione_erogazione'] == x['regione_erogazione']) & (incremento_percentuale_medio['quadrimestre'] == x['quadrimestre'])]['incremento_teleassistenze'].values[0], axis=1)
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1413, in _LocIndexer._getitem_axis(self, key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
# -> 1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#    1416     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1211, in _LocationIndexer._getbool_axis(self, key, axis)
#    1209 key = check_bool_indexer(labels, key)
#    1210 inds = key.nonzero()[0]
# -> 1211 return self.obj._take_with_is_copy(inds, axis=axis)
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4142 @final
#    4143 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4144     """
#    4145     Internal version of the `take` method that sets the `_is_copy`
#    4146     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151     See the docstring of `take` for full explanation of the parameters.
#    4152     """
# -> 4153     result = self.take(indices=indices, axis=axis)
#    4154     # Maybe set copy if we didn't actually change the index.
#    4155     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:705, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     702 if axis == 1:
#     703     # We can avoid the need to rebuild these
#     704     new_mgr._blknos = self.blknos.copy()
# --> 705     new_mgr._blklocs = self.blklocs.copy()
#     706 return new_mgr
#
# File ~/ucbm/fia/Teleassistance-Supervised-Clustering/.venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:196, in BaseBlockManager.blklocs(self)
#     192         self._rebuild_blknos_and_blklocs()
#     194     return self._blknos
# --> 196 @property
#     197 def blklocs(self) -> npt.NDArray[np.intp]:
#     198     """
#     199     See blknos.__doc__
#     200     """
#     201     if self._blklocs is None:
#     202         # Note: these can be altered by other BlockManager methods.
#
# KeyboardInterrupt:

# %%
df
# Out:
#         id_prenotazione       id_paziente              data_nascita   sesso  \
# 0       JUOCPQCUG1H96QO  LCWFXF28X79P382V 1980-04-24 00:00:00+00:00    male
# 1       XDP99NXRHPOYFYU  LRFZOI94E58U012I 1972-01-30 00:00:00+00:00  female
# 2       6VYI0AK57ECO5WU  JOBCGJ98A04B765H 1986-06-27 00:00:00+00:00    male
# 3       VLFS5J9E3Q74Q2W  TKROSE51Z77Q065E 1967-10-21 00:00:00+00:00  female
# 4       XD8SZX9JOVCMEXW  WRRVSK73Z45L640S 1963-08-24 00:00:00+00:00    male
# ...                 ...               ...                       ...     ...
# 484286  NWGQXYJLAZTSXK5  PHBJZU46U44B472M 1979-08-09 00:00:00+00:00    male
# 484287  HIQTBNMIKME07RG  IINZRZ57L35P744I 1961-05-26 00:00:00+00:00  female
# 484288  I9L0K7HGMZDMXQ9  QAKHUY72D19M465N 2014-10-31 00:00:00+00:00    male
# 484289  UAMI5JIJUN80FOK  OOUVZJ15J93N500X 2011-08-18 00:00:00+00:00  female
# 484290  OENSBU44YHD6T3I  EOTJNS20F47F620H 2022-08-30 00:00:00+00:00    male
#
#        regione_residenza               asl_residenza provincia_residenza  \
# 0               Piemonte                         CN1               Cuneo
# 1                Toscana  AZIENDA USL TOSCANA CENTRO             Firenze
# 2         Emilia romagna         AZIENDA USL BOLOGNA             Bologna
# 3               Campania      A.S.L. NAPOLI 1 CENTRO              Napoli
# 4                Abruzzo                     PESCARA             Pescara
# ...                  ...                         ...                 ...
# 484286          Calabria              A.S.P. COSENZA             Cosenza
# 484287         Lombardia           ATS DELL'INSUBRIA              Varese
# 484288            Puglia                      ASL FG              Foggia
# 484289          Campania      A.S.L. NAPOLI 1 CENTRO              Napoli
# 484290          Calabria      A.S.P. REGGIO CALABRIA     Reggio Calabria
#
#        comune_residenza tipologia_servizio  \
# 0               Fossano     Teleassistenza
# 1             Calenzano     Teleassistenza
# 2               Bologna     Teleassistenza
# 3                Napoli     Teleassistenza
# 4               Pescara     Teleassistenza
# ...                 ...                ...
# 484286  Montalto Uffugo     Teleassistenza
# 484287   Somma Lombardo     Teleassistenza
# 484288           Foggia     Teleassistenza
# 484289           Napoli     Teleassistenza
# 484290            Stilo     Teleassistenza
#
#                                      descrizione_attivita  ...  \
# 0       Insegnamento al paziente e/o alla sua famiglia...  ...
# 1       Prestazione infermieristica connessa alla nece...  ...
# 2                                  Prestazione dietistica  ...
# 3                                Psicoterapia individuale  ...
# 4                                  Prestazione dietistica  ...
# ...                                                   ...  ...
# 484286  Addestramento del paziente e/o famiglia in cas...  ...
# 484287  Prestazione infermieristica relativa alla funz...  ...
# 484288                           Intervento fisioterapico  ...
# 484289  Intervento di educazione e prevenzione in ambi...  ...
# 484290  Educazione del paziente e/o dei suoi familiari...  ...
#
#        codice_struttura_erogazione     tipologia_struttura_erogazione  \
# 0                            10906                Azienda Ospedaliera
# 1                            90904  Azienda Ospedaliera Universitaria
# 2                            80053        Ospedale a gestione diretta
# 3                           150902                Azienda Ospedaliera
# 4                           130018        Ospedale a gestione diretta
# ...                            ...                                ...
# 484286                      180010        Ospedale a gestione diretta
# 484287                       30901        Ospedale a gestione diretta
# 484288                      160905                   Fondazione IRCCS
# 484289                      150903                Azienda Ospedaliera
# 484290                      180059        Ospedale a gestione diretta
#
#        id_professionista_sanitario tipologia_professionista_sanitario  \
# 0                 MZRAER00D13A287J                         Infermiere
# 1                 EBCRPU12T24U316I                         Infermiere
# 2                 PMEJNL62M27F357I                           Dietista
# 3                 VNNRMQ15C69W200K                          Psicologo
# 4                 GIQCNR34T04P154U                           Dietista
# ...                            ...                                ...
# 484286            LDOGNN68P28V217R                         Infermiere
# 484287            QJRGNR36W85W322L                         Infermiere
# 484288            LUSQEC01O34D921X                     Fisioterapista
# 484289            EZXYPG62R63K538T                        Ostetrica/o
# 484290            HEDODF11X53L647F                         Infermiere
#
#                  data_erogazione  durata_erogazione_min eta  anno  \
# 0      2019-02-04 10:00:00+00:00                 2925.0  44  2019
# 1      2019-02-01 10:00:00+00:00                 1895.0  52  2019
# 2      2019-02-03 06:00:00+00:00                 1165.0  38  2019
# 3      2019-02-01 06:00:00+00:00                 1969.0  56  2019
# 4      2019-02-05 14:00:00+00:00                 3099.0  61  2019
# ...                          ...                    ...  ..   ...
# 484286 2022-12-30 14:00:00+00:00                 2388.0  45  2022
# 484287 2022-12-31 13:00:00+00:00                 1524.0  63  2022
# 484288 2022-12-30 17:00:00+00:00                 3081.0   9  2022
# 484289 2022-12-31 15:00:00+00:00                 2279.0  12  2022
# 484290 2022-12-31 16:00:00+00:00                 3123.0   1  2022
#
#        quadrimestre incremento_teleassistenze
# 0                 1            high_increment
# 1                 1            high_increment
# 2                 1            high_increment
# 3                 1            high_increment
# 4                 1            high_increment
# ...             ...                       ...
# 484286            4             low_increment
# 484287            4          medium_increment
# 484288            4             low_increment
# 484289            4             low_increment
# 484290            4             low_increment
#
# [460509 rows x 25 columns]
